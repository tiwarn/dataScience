# %%
pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/a1/70/618c9795fcf31768f59060db89bba7cafe9ae180064cb5206948c8c33295/mysql_connector_python-9.0.0-cp312-cp312-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.3 MB 653.6 kB/s eta 0:00:22
#    - -------------------------------------- 0.7/14.3 MB 5.2 MB/s eta 0:00:03
#    -------- ------------------------------- 3.2/14.3 MB 16.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.0/14.3 MB 25.5 MB/s eta 0:00:01
#    ------------------------ --------------- 8.7/14.3 MB 30.6 MB/s eta 0:00:01
#    ------------------------------- -------- 11.2/14.3 MB 54.7 MB/s eta 0:00:01
# ...

# %%
import mysql.connector

try:
    # Create a connection to the MySQL server
    obj=mysql.connector.connect(
        host='localhost',
        user='root',
        password='Erbipin@56',
    )

# create a cursor to interact with the database
    cursor=obj.cursor()
    print("Connection established")
except:
    print("Connection Error")

#finally:

    # Don't forget to close the cursor and connection when you're done
    #cursor.close()
    #obj.close()

# %% [markdown]
# # Python Connecttivity

# %% [markdown]
# - Python is powerfull language
# - Python is high level language

# %% [markdown]
# ## Application
# >- <b> Youtube </b>
# ***
# >- <i> Facebook </i>
# >>- <U> Instagram </U>

# %% [markdown]
# ![image.png](attachment:d13b3c54-b592-46a0-8478-51bb25f21370.png)

# %%
cursor.execute('''
    create database Fi''')

obj.commit()

# %%
cursor.execute('''
    use Fi''')

obj.commit()

# %%
cursor.execute('''
    create table airport(
    ID int(10),
    code varchar(10),
    name varchar(10)
    )''')

obj.commit()

# %%
# Insert data to the table
cursor.execute("""
    INSERT INTO Airport VALUES (1,"DEL", "NEW DELHI"),
    (2,'CCU','Kolkata'),
    (3,"BOM","Mumbai")""")

# %%
cursor.execute("SELECT * FROM airport")
dd =cursor.fetchall()
print(dd)
# Out:
# [(1, 'DEL', 'NEW DELHI'), (2, 'CCU', 'Kolkata'), (3, 'BOM', 'Mumbai')]

# %%
# Search/Retrieve
cursor.execute("SELECT * FROM airport WHERE id > 1")
data = cursor.fetchall()
print(data)
# Out:
# [(2, 'CCU', 'Kolkata'), (3, 'BOM', 'Mumbai')]
