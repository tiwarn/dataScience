# %%
import qrcode
import matplotlib.pyplot as plt

# %%
data='https://www.youtube.com/watch?v=0Mua9whWvhY'

# %%
file_name="my_qr_code.png"

# %%
image=qrcode.make(data)

# %%
image.save(file_name)

# %%
plt.imshow(image,cmap='gray')
