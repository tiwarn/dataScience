# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\Admin\Desktop\Viska\Machine Learning\Assignment/assignment_6_outlier2.xlsx")
df.head()
# Out:
#          location       size  total_sqft  bath    price  bhk  price_per_sqft
# 0  Coconut Garden      3 BHK      1800.0     3    80.00    3     4444.444444
# 1      Binny Pete      1 BHK       665.0     1    50.75    1     7631.578947
# 2      Chamrajpet  9 Bedroom      4050.0     7  1200.00    9    29629.629630
# 3       TC Palaya  3 Bedroom      1500.0     2   100.00    3     6666.666667
# 4         Kalkere      2 BHK       925.0     2    48.00    2     5189.189189

# %%
df.tail()
# Out:
#                   location       size  total_sqft  bath  price  bhk  \
# 914                 Ulsoor      3 BHK      1020.0     3  110.0    3
# 915   Outer Ring Road East      2 BHK      1198.0     2   84.0    2
# 916  5th block Koramangala      4 BHK      4000.0     4  520.0    4
# 917            Nelamangala  4 Bedroom      1470.0     4   34.5    4
# 918        JakkurYelahanka      2 BHK      1370.0     2   75.0    2
#
#      price_per_sqft
# 914    10784.313730
# 915     7011.686144
# 916    13000.000000
# 917     2346.938776
# 918     5474.452555

# %%
df.shape
# Out:
# (919, 7)

# %%
df.shape[0]
# Out:
# 919

# %%
df.shape[1]
# Out:
# 7

# %%
df.columns
# Out:
# Index(['location', 'size', 'total_sqft', 'bath', 'price', 'bhk',
#        'price_per_sqft'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        919 non-null    object
#  1   size            919 non-null    object
#  2   total_sqft      919 non-null    float64
#  3   bath            919 non-null    int64
#  4   price           919 non-null    float64
#  5   bhk             919 non-null    int64
#  6   price_per_sqft  919 non-null    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 50.4+ KB

# %%
df.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# price_per_sqft    0
# dtype: int64

# %%
df.describe()
# Out:
#          total_sqft        bath        price         bhk  price_per_sqft
# count    919.000000  919.000000   919.000000  919.000000      919.000000
# mean    1575.201518    2.724701   107.935702    2.841132     6635.653763
# std     1879.661306    1.586074   114.429376    1.496112     4041.660903
# min      340.000000    1.000000    10.000000    1.000000      267.829813
# 25%     1100.000000    2.000000    50.000000    2.000000     4274.521531
# 50%     1277.500000    2.000000    72.000000    3.000000     5511.111111
# 75%     1654.500000    3.000000   120.000000    3.000000     7397.109610
# max    52272.000000   27.000000  1200.000000   27.000000    50000.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=919, step=1)

# %%
Max_thresold=df['price_per_sqft'].quantile(0.97)
Max_thresold
# Out:
# 16065.909091399973

# %%
df[df['price_per_sqft']>Max_thresold]
# Out:
#                    location        size  total_sqft  bath   price  bhk  \
# 2                Chamrajpet   9 Bedroom      4050.0     7  1200.0    9
# 14           D Souza Layout       3 BHK      4634.0     4  1015.0    3
# 17             Malleshwaram   8 Bedroom       840.0     7   195.0    8
# 82    1st Block HRBR Layout   8 Bedroom      1200.0     7   235.0    8
# 107               Kodihalli       4 BHK      3073.0     5   696.0    4
# 141     9th Block Jayanagar   1 Bedroom       700.0     1   150.0    1
# 192            Malleshwaram   9 Bedroom       750.0     8   150.0    9
# 194      9th Phase JP Nagar   7 Bedroom      1200.0     6   195.0    7
# 258                  Ulsoor       3 BHK      2700.0     3   450.0    3
# 269             Uttarahalli   5 Bedroom       400.0     5   200.0    5
# 371    2nd Stage Nagarbhavi   4 Bedroom      1200.0     4   245.0    4
# 380              Whitefield   5 Bedroom      3250.0     5   900.0    5
# ...

# %%
Min_thresold=df['price_per_sqft'].quantile(0.03)
Min_thresold
# Out:
# 2909.5968168199997

# %%
df[df['price_per_sqft']>Min_thresold]
# Out:
#                   location       size  total_sqft  bath    price  bhk  \
# 0           Coconut Garden      3 BHK      1800.0     3    80.00    3
# 1               Binny Pete      1 BHK       665.0     1    50.75    1
# 2               Chamrajpet  9 Bedroom      4050.0     7  1200.00    9
# 3                TC Palaya  3 Bedroom      1500.0     2   100.00    3
# 4                  Kalkere      2 BHK       925.0     2    48.00    2
# ..                     ...        ...         ...   ...      ...  ...
# 913              Bellandur      3 BHK      2039.0     3   168.00    3
# 914                 Ulsoor      3 BHK      1020.0     3   110.00    3
# 915   Outer Ring Road East      2 BHK      1198.0     2    84.00    2
# 916  5th block Koramangala      4 BHK      4000.0     4   520.00    4
# 918        JakkurYelahanka      2 BHK      1370.0     2    75.00    2
#
#      price_per_sqft
# 0       4444.444444
# 1       7631.578947
# 2      29629.629630
# 3       6666.666667
# ...

# %%
df2=df[(df.price_per_sqft<Max_thresold)&(df.price_per_sqft>Min_thresold)]
df2.shape
# Out:
# (863, 7)

# %%
df.shape
# Out:
# (919, 7)

# %% [markdown]
# **Other Method**

# %%
#other method
min_thresold,max_thresold=df.price_per_sqft.quantile([0.03,0.97])
min_thresold,max_thresold
# Out:
# (2909.5968168199997, 16065.909091399973)

# %%
df[df['price_per_sqft']>max_thresold]
# Out:
#                    location        size  total_sqft  bath   price  bhk  \
# 2                Chamrajpet   9 Bedroom      4050.0     7  1200.0    9
# 14           D Souza Layout       3 BHK      4634.0     4  1015.0    3
# 17             Malleshwaram   8 Bedroom       840.0     7   195.0    8
# 82    1st Block HRBR Layout   8 Bedroom      1200.0     7   235.0    8
# 107               Kodihalli       4 BHK      3073.0     5   696.0    4
# 141     9th Block Jayanagar   1 Bedroom       700.0     1   150.0    1
# 192            Malleshwaram   9 Bedroom       750.0     8   150.0    9
# 194      9th Phase JP Nagar   7 Bedroom      1200.0     6   195.0    7
# 258                  Ulsoor       3 BHK      2700.0     3   450.0    3
# 269             Uttarahalli   5 Bedroom       400.0     5   200.0    5
# 371    2nd Stage Nagarbhavi   4 Bedroom      1200.0     4   245.0    4
# 380              Whitefield   5 Bedroom      3250.0     5   900.0    5
# ...

# %%
df[df['price_per_sqft']<min_thresold]
# Out:
#                         location       size  total_sqft  bath    price  bhk  \
# 18               Electronic City      2 BHK       710.0     2   16.000    2
# 84                    Chandapura      2 BHK       850.0     1   18.500    2
# 197              Electronic City      2 BHK      1130.0     2   32.640    2
# 210                 Ananth Nagar      2 BHK      1100.0     2   31.500    2
# 224                   Chandapura      2 BHK      1201.0     2   27.000    2
# 244               Sarjapur  Road      1 BHK       615.0     1   17.835    1
# 336                 Karuna Nagar      3 BHK      1200.0     2   34.000    3
# 364     Electronic City Phase II      2 BHK      1000.0     2   28.880    2
# 365                 Ananth Nagar      2 BHK       982.0     2   24.550    2
# 373                    Herohalli  5 Bedroom      1800.0     6   44.500    5
# 397                       Huskur      2 BHK      1090.0     2   31.480    2
# ...

# %%
df3=df[(df.price_per_sqft<max_thresold)&(df.price_per_sqft>min_thresold)]
df3.shape
# Out:
# (863, 7)

# %%
df.shape
# Out:
# (919, 7)
