# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\Viska\Machine Learning\Day14-19-May-24-Project K Mean/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=df.drop(columns="Outcome",axis=1)
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df[['Outcome']]
y
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
x.shape
# Out:
# (768, 8)

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75, random_state=42)

# %%
#Scalling our database
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit(x_train)
x_train_sc=sc.transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
#PCA

# %%
from sklearn.decomposition import PCA

# %%
pca1=PCA(n_components=5)
pca1.fit(x_train_sc)
# Out:
# PCA(n_components=5)

# %%
x_train_sc_pca = pca1.transform(x_train_sc)
x_test_sc_pca = pca1.transform(x_test_sc)

# %%
x_train_sc.shape
# Out:
# (576, 8)

# %%
x_train_sc_pca.shape
# Out:
# (576, 5)

# %%
# Once you get the new components, you can apply any classification machine learning algorithms

# %%
pd.DataFrame(x_train_sc_pca)
# Out:
#             0         1         2         3         4
# 0    0.005923  1.272467  1.179144  0.658285  3.592799
# 1    0.927700 -0.678114 -0.302794 -1.294647 -0.274699
# 2   -0.486815  0.463172 -1.916622  0.451375  0.444897
# 3   -0.934697 -0.721828 -0.384462  0.530149 -0.146969
# 4   -2.559639 -0.637606  1.055560  0.272422 -0.485278
# ..        ...       ...       ...       ...       ...
# 571  0.440111 -0.539627  0.341392 -0.544737  0.652093
# 572 -1.198907  0.608611 -1.422500 -0.259479 -2.398158
# 573  1.937145  0.719048 -1.237310  2.524656  0.783214
# 574 -1.778476 -0.864794  1.559243 -0.771334  0.449043
# 575 -1.426585 -0.036119 -0.233241 -0.522793 -2.191465
#
# [576 rows x 5 columns]
