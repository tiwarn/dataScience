# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

from sklearn import linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# assignment - 1 (simple linear regression)
#
#
# gold price prediction
#
# year = 2020
# year = 2025

# %%
#import data
df1=pd.read_csv(r"C:\Users\Admin\Desktop\Viska\Machine Learning\Assignment/assignment_1_linear.csv")
df1
# Out:
#    Year  Gold_price
# 0  2016       30000
# 1  2018       35000
# 2  2019       40000
# 3  2021       45000
# 4  2022       50000

# %%
#remove dependent data
new_df=df1.drop('Gold_price',axis=1)
new_df
# Out:
#    Year
# 0  2016
# 1  2018
# 2  2019
# 3  2021
# 4  2022

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df1.Gold_price)
# Out:
# LinearRegression()

# %%
model.predict([[2020]])
# Out:
# array([42631.57894737])

# %%
model.predict([[2025]])
# Out:
# array([59078.94736842])

# %% [markdown]
# assignment - 2 (multiple linear regression)
#
# experience = 10
# test score = 10
# interview score = 10
#
#
# experience = 10
# test score = 5
# interview score = 5

# %%
#import data
df=pd.read_csv(r"C:\Users\Admin\Desktop\Viska\Machine Learning\Assignment/assignment_2_linear.csv")
df
# Out:
#    experience  test_score  interview_score  salary
# 0         NaN           8                9   50000
# 1         NaN           8                6   45000
# 2         5.0           6                7   60000
# 3         2.0          10               10   65000
# 4         7.0           9                6   70000
# 5         3.0           7               10   62000
# 6        10.0           8                7   72000
# 7        11.0           7                8   80000

# %%
#fill the null value
df.loc[0,'experience']=9
df.loc[1,'experience']=8
df
# Out:
#    experience  test_score  interview_score  salary
# 0         9.0           8                9   50000
# 1         8.0           8                6   45000
# 2         5.0           6                7   60000
# 3         2.0          10               10   65000
# 4         7.0           9                6   70000
# 5         3.0           7               10   62000
# 6        10.0           8                7   72000
# 7        11.0           7                8   80000

# %%
#remove dependent variable
new_df=df.drop('salary',axis=1)
new_df
# Out:
#    experience  test_score  interview_score
# 0         9.0           8                9
# 1         8.0           8                6
# 2         5.0           6                7
# 3         2.0          10               10
# 4         7.0           9                6
# 5         3.0           7               10
# 6        10.0           8                7
# 7        11.0           7                8

# %%
model=linear_model.LinearRegression()
model.fit(new_df,df.salary)
# Out:
# LinearRegression()

# %%
model.predict([[10,10,10]])
# Out:
# array([69961.14001565])

# %%
model.predict([[10,5,5]])
# Out:
# array([61268.06022377])
