# %%
#import library
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1.use iris dataset

# %%
#import data
df=pd.read_csv(r"C:\Users\Admin\Desktop\Viska\EDA/Iris.csv")
df.sample(90)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 139  140            6.9           3.1            5.4           2.1
# 105  106            7.6           3.0            6.6           2.1
# 32    33            5.2           4.1            1.5           0.1
# 60    61            5.0           2.0            3.5           1.0
# 72    73            6.3           2.5            4.9           1.5
# ..   ...            ...           ...            ...           ...
# 124  125            6.7           3.3            5.7           2.1
# 14    15            5.8           4.0            1.2           0.2
# 43    44            5.0           3.5            1.6           0.6
# 24    25            4.8           3.4            1.9           0.2
# 90    91            5.5           2.6            4.4           1.2
#
#              Species
# 139   Iris-virginica
# 105   Iris-virginica
# 32       Iris-setosa
# 60   Iris-versicolor
# 72   Iris-versicolor
# ..               ...
# ...

# %%
#For univariate analysis  - use PetalLengthCm

# %%
df1=df.loc[df["Species"]=="Iris-virginica"]
df1.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica

# %%
df2=df.loc[df["Species"]=="Iris-setosa"]
df2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df3=df.loc[df["Species"]=="Iris-versicolor"]
df3.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
#
#             Species
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor

# %%
plt.plot(df1['SepalLengthCm'],np.zeros_like(df1['SepalLengthCm']),"*")
plt.plot(df2["SepalLengthCm"],np.zeros_like(df2['SepalLengthCm']),"+")
plt.plot(df3['SepalLengthCm'],np.zeros_like(df3['SepalLengthCm']),".")

# %%
len(df.loc[50:100])
# Out:
# 51

# %%
#bivariate analysis (only take 2 features - "SepalLengthCm","SepalWidthCm")

# %%
sns.FacetGrid(df,hue="Species",height=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm")

# %%
sns.FacetGrid(df,hue="Species",height=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend();

# %%
sns.pairplot(df,hue='Species',height=4).add_legend()

# %%
#univariant:-np.zeros_like(For Singal values
#BIvariant:-sns.Facetgrid(df,hue-"Species").map(plt.scatter)
#Multivariant:-sns.pairplot(df,hue="Sepcies")

# %%
sns.pairplot(df,x_vars=["SepalLengthCm","PetalWidthCm"],y_vars=['Species'],height=4)

# %%
sns.pairplot(df,x_vars=["SepalLengthCm","SepalWidthCm"],y_vars=['Species',],height=4,aspect=1)

# %%
sns.pairplot(df,x_vars=["PetalLengthCm","PetalWidthCm"],y_vars=['Species'],height=4,aspect=1)
