# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
#                                                   ***Feature Scaling***

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Normalization.PNG")

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Normalization1.PNG")

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Normalizatio2.PNG")

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\ML Practice\ML_100_Day Data/wine_data.csv",header=None,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic acid']
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            1    14.23        1.71
# 1            1    13.20        1.78
# 2            1    13.16        2.36
# 3            1    14.37        1.95
# 4            1    13.24        2.59

# %%
df.shape
# Out:
# (178, 3)

# %%
import matplotlib.pyplot as plt
fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(10,4))
sns.kdeplot(df['Alcohol'],ax=ax1)
sns.kdeplot(df['Malic acid'],ax=ax2)
plt.show()

# %%
import seaborn as sns

color_dict = {1: 'red', 2: 'blue', 3: 'green'}

sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'], hue=df['Class label'], palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('Class label',axis=1),df['Class label'],test_size=0.3,random_state=0)

# %%
X_train.head
# Out:
# <bound method NDFrame.head of      Alcohol  Malic acid
# 22     13.71        1.86
# 108    12.22        1.29
# 175    13.27        4.28
# 145    13.16        3.57
# 71     13.86        1.51
# ..       ...         ...
# 103    11.82        1.72
# 67     12.37        1.17
# 117    12.42        1.61
# 47     13.90        1.68
# 172    14.16        2.51
#
# [124 rows x 2 columns]>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)
#Transform train and test set
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled= pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled= pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(X_train['Alcohol'],X_train['Malic acid'], c=y_train)
ax1.set_title('Before Scaling')

ax2.scatter(X_train_scaled['Alcohol'],X_train_scaled['Malic acid'], c=y_train)
ax2.set_title('After Scaling')
plt.plot()
# Out:
# []

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)

# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
 #Min & Max scaling can't work with outliers.

# %% [markdown]
#                                                 ***Mean Normalization***

# %% [markdown]
# # here we are doing mean centring of the data, It's range of [-1 : 1] but mostly we are use satndardscaler instead of this.

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Mean_Scaling.PNG")

# %% [markdown]
#                                                         ****Max_Abs_Scaling****

# %%
#Max_abs_Scalling is use with sparce type of data where maximum data is zero.

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Max_Abs_Scaling.PNG")

# %% [markdown]
#                                                         ****Robust Scaling****

# %%
#Robust scaling is mostly used where outliers are available in the dataset.

# %%
from IPython.display import Image
Image(filename = "C:/Users/Admin/Desktop/ML Practice/ML_100_Day Data/Robust.PNG")

# %% [markdown]
# we have few click points :
# 1.Is feature scaling required: It's depends on the dataset if you are working with a decision tree, then it's not required.
# 2. Monthly we are using standardization  and normalization will be use you know your minimum and maximum value then mostaly we can use min_Max ex. Image processing in CNN.
# 3.If you know we have outlier in our dataset then use "Robust_Scaling"
# 4.If you have maximum data is"Zero" then use "Max_Abs_Scaling".
# 5.If you don't know anything about the data the use "standardization"
