# %% [markdown]
# import pandas as pd
# import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %% [markdown]
# temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df = response.json()

# %%
temp_df
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 28.9082,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.711,
#    'vote_count': 28408},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
#convert in dataframe
temp_df=pd.DataFrame(response.json())
temp_df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...          509
# 1      1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...          509
# 2      1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          509
# 3      1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          509
# 4      1  {'adult': False, 'backdrop_path': '/bxgTSUenZD...          509
# 5      1  {'adult': False, 'backdrop_path': '/m4TUa2ciEW...          509
# 6      1  {'adult': False, 'backdrop_path': '/enNubozHn9...          509
# 7      1  {'adult': False, 'backdrop_path': '/90ez6ArvpO...          509
# 8      1  {'adult': False, 'backdrop_path': '/amZavErrjr...          509
# 9      1  {'adult': False, 'backdrop_path': '/hiKmpZMGZs...          509
# 10     1  {'adult': False, 'backdrop_path': '/suaEOtk1N1...          509
# 11     1  {'adult': False, 'backdrop_path': '/2u7zbn8Eud...          509
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])
temp_df
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]     389
# 5   False  /m4TUa2ciEWSlk37rOsjiSIvZDXE.jpg   [16, 10751, 14]     129
# 6   False   /enNubozHn9pXi0ycTVYUWfpHZm.jpg  [18, 28, 80, 53]     155
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 8   False  /amZavErrjrdgDwhsIdpWxHNenIx.jpg      [14, 18, 80]     497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 10  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 11  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# ...

# %%
#select the required column from results data.
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
temp_df.shape
# Out:
# (20, 7)

# %%
#here created new database
df = pd.DataFrame()

# %% [markdown]
# #Here you get the error "'DataFrame' object has no attribute 'append'" so use below one.
# for i in range(1,429):
#     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
#     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#     df = df.append(temp_df,ignore_index=True)

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (8560, 7)

# %%
#here Data saved in jupyter folder
df.to_csv('movies.csv')
